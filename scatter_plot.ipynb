# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/dataset_train.csv', index_col = 0)
df
# Out:
#       Hogwarts House First Name    Last Name    Birthday Best Hand  \
# Index
# 0          Ravenclaw     Tamara          Hsu  2000-03-30      Left
# 1          Slytherin      Erich      Paredes  1999-10-14     Right
# 2          Ravenclaw   Stephany        Braun  1999-11-03      Left
# 3         Gryffindor      Vesta    Mcmichael  2000-08-19      Left
# 4         Gryffindor     Gaston        Gibbs  1998-09-27      Left
# ...              ...        ...          ...         ...       ...
# 1595      Gryffindor       Jung        Blank  2001-09-14     Right
# 1596       Slytherin     Shelli         Lock  1998-03-12      Left
# 1597      Gryffindor   Benjamin  Christensen  1999-10-24     Right
# 1598      Hufflepuff  Charlotte       Dillon  2001-09-21      Left
# 1599      Hufflepuff      Kylie        Nowak  2000-08-21      Left
#
#        Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# Index
# 0         58384.0 -487.886086   5.727180                       4.878861
# ...

# %%
# What are the two features that are similar ?
# Answer: Care of Magical Creatures

# %%
fig, ax = plt.subplots()
Gryffindor_x = df['Astronomy'][df['Hogwarts House'] == 'Gryffindor']
Gryffindor_y = df['Defense Against the Dark Arts'][df['Hogwarts House'] == 'Gryffindor']
Slytherin_x = df['Astronomy'][df['Hogwarts House'] == 'Slytherin']
Slytherin_y = df['Defense Against the Dark Arts'][df['Hogwarts House'] == 'Slytherin']
Ravenclaw_x = df['Astronomy'][df['Hogwarts House'] == 'Ravenclaw']
Ravenclaw_y = df['Defense Against the Dark Arts'][df['Hogwarts House'] == 'Ravenclaw']
Hufflepuff_x = df['Astronomy'][df['Hogwarts House'] == 'Hufflepuff']
Hufflepuff_y = df['Defense Against the Dark Arts'][df['Hogwarts House'] == 'Hufflepuff']

ax.scatter(Gryffindor_x, Gryffindor_y, color='yellow', alpha=0.4, marker='*', cmap='viridis')
ax.scatter(Slytherin_x, Slytherin_y, color='blue', alpha=0.4, marker='*', cmap='viridis')
ax.scatter(Ravenclaw_x, Ravenclaw_y, color='red', alpha=0.4, marker='*', cmap='viridis')
ax.scatter(Hufflepuff_x , Hufflepuff_y, color='green', alpha=0.4, marker='*', cmap='viridis')
plt.xlabel('Astronomy')
plt.ylabel('Defense Against the Dark Arts')
# Out:
# Text(0, 0.5, 'Defense Against the Dark Arts')

# %%
import plotly.express as px

#fig = px.scatter(df, x="Astronomy", y="Defense Against the Dark Arts", color="Hogwarts House", animation_frame = "Hogwarts House")
fig = px.scatter(df, x="Astronomy", y="Defense Against the Dark Arts", color="Hogwarts House")

fig.show()
# Out:
# <div>                            <div id="7202005b-209d-47ad-ba08-ec9c6bbc0dfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7202005b-209d-47ad-ba08-ec9c6bbc0dfc")) {                    Plotly.newPlot(                        "7202005b-209d-47ad-ba08-ec9c6bbc0dfc",                        [{"hovertemplate":"Hogwarts House=Ravenclaw<br>Astronomy=%{x}<br>Defense Against the Dark Arts=%{y}<extra></extra>","legendgroup":"Ravenclaw","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Ravenclaw","showlegend":true,"x":[-487.88608595139016,-366.0761168823237,-197.52731769185084,-447.6498122360021,-151.08820873346482,-264.6783109979997,-511.2264383563732,-301.4833725111648,-766.5199010356482,-279.0010918745341,-591.878579651734,-415.0263
# ...
